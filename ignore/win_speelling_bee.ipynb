# %%
from spelling_bee import Spelling_Bee

# %%
characters = list('rautlyf')
bee = Spelling_Bee(characters, 'f')
# Out:
# Current size of corpus: 370103

# %%
bee.remove_short_words()
bee.remove_non_center_words()
# Out:
# 370103

# %%
corpus = bee.word_list

# %%
winners = bee.check_corpus()
winners
# Out:
# ['afar',
#  'afara',
#  'affa',
#  'affy',
#  'affray',
#  'afft',
#  'aflat',
#  'afray',
#  'alfa',
#  'alfalfa',
#  'alfur',
#  'artful',
#  'artfully',
#  'faff',
#  'faffy',
#  'fayal',
#  'fala',
#  'fall',
#  'falla',
#  'fallal',
#  'fally',
#  'farfal',
#  'farfara',
#  'farl',
#  'fart',
#  'fatal',
#  'fatally',
#  'fatly',
#  'fatty',
#  'fault',
#  'faultful',
#  'faultfully',
#  'faulty',
#  'faut',
#  'flaff',
#  'flay',
#  'flary',
#  'flat',
#  'flatly',
#  'fluff',
#  'fluffy',
#  'fluyt',
#  'flurr',
#  'flurry',
#  'flurt',
#  'fluty',
#  'fray',
#  'frary',
#  'frat',
#  'fratry',
#  'frau',
#  'fuff',
#  'fuffy',
#  'fula',
#  'fulful',
#  'full',
#  'fully',
#  'fural',
#  'furfur',
#  'furfural',
#  'furfuryl',
#  'fury',
#  'furyl',
#  'furl',
#  'furry',
#  'futural',
#  'yaff',
#  'yuft',
#  'laft',
#  'luff',
#  'luffa',
#  'raff',
#  'raft',
#  'rafty',
#  'rayful',
#  'ralf',
#  'ruff',
#  'ruffly',
#  'taffy',
#  'taft',
#  'taraf',
#  'tarfa',
#  'trayful',
#  'truff',
#  'tufa',
#  'tuff',
#  'tuft',
#  'tufty',
#  'turf',
#  'turfy']

# %%
from trie import *
trie = Trie()

# %%
f = open('words_alpha.txt', 'r')
word_list = f.readlines()
f.close()

# %%
corpus = []
for word in word_list:
    trie.add(word)

trie.number_nodes
# Out:
# ic
#
# adding the word:  zymotically
#
# adding the word:  zymotize
#
# adding the word:  zymotoxic
#
# adding the word:  zymurgy
#
# adding the word:  zymurgies
#
# adding the word:  zinc
#
# adding the word:  zincalo
#
# adding the word:  zincate
#
# adding the word:  zincates
#
# adding the word:  zinced
#
# adding the word:  zincenite
#
# adding the word:  zincy
#
# adding the word:  zincic
#
# adding the word:  zincid
#
# adding the word:  zincide
#
# adding the word:  zinciferous
#
# adding the word:  zincify
#
# adding the word:  zincification
#
# adding the word:  zincified
#
# adding the word:  zincifies
#
# adding the word:  zincifying
#
# adding the word:  zincing
#
# adding the word:  zincite
#
# adding the word:  zincites
#
# adding the word:  zincize
#
# adding the word:  zincke
#
# adding the word:  zincked
#
# adding the word:  zinckenite
#
# adding the word:  zincky
#
# adding the word:  zincking
#
# adding the word:  zinco
#
# adding the word:  zincode
#
# adding the word:  zincograph
#
# adding the word:  zincographer
#
# adding the word:  zincography
#
# adding the word:  zincographic
#
# adding the word:  zincographical
#
# adding the word:  zincoid
#
# adding the word:  zincolysis
#
# adding the word:  zincotype
#
# adding the word:  zincous
#
# adding the word:  zincs
#
# adding the word:  zincum
#
# adding the word:  zincuret
#
# adding the word:  zindabad
#
# adding the word:  zindiq
#
# adding the word:  zineb
#
# adding the word:  zinebs
#
# adding the word:  zinfandel
#
# adding the word:  zing
#
# adding the word:  zingana
#
# adding the word:  zingani
#
# adding the word:  zingano
#
# adding the word:  zingara
#
# adding the word:  zingare
#
# adding the word:  zingaresca
#
# adding the word:  zingari
#
# adding the word:  zingaro
#
# adding the word:  zinged
#
# adding the word:  zingel
#
# adding the word:  zinger
#
# adding the word:  zingerone
#
# adding the word:  zingers
#
# adding the word:  zingy
#
# adding the word:  zingiber
#
# adding the word:  zingiberaceae
#
# adding the word:  zingiberaceous
#
# adding the word:  zingiberene
#
# adding the word:  zingiberol
#
# adding the word:  zingiberone
#
# adding the word:  zingier
#
# adding the word:  zingiest
#
# adding the word:  zinging
#
# adding the word:  zings
#
# adding the word:  zinyamunga
#
# adding the word:  zinjanthropi
#
# adding the word:  zinjanthropus
#
# adding the word:  zink
#
# adding the word:  zinke
#
# adding the word:  zinked
#
# adding the word:  zinkenite
#
# adding the word:  zinky
#
# adding the word:  zinkiferous
#
# adding the word:  zinkify
#
# adding the word:  zinkified
#
# adding the word:  zinkifies
#
# adding the word:  zinkifying
#
# adding the word:  zinnia
#
# adding the word:  zinnias
#
# adding the word:  zinnwaldite
#
# adding the word:  zinober
#
# adding the word:  zinsang
#
# adding the word:  zinzar
#
# adding the word:  zinziberaceae
#
# adding the word:  zinziberaceous
#
# adding the word:  zion
#
# adding the word:  zionism
#
# adding the word:  zionist
#
# adding the word:  zionistic
#
# adding the word:  zionists
#
# adding the word:  zionite
#
# adding the word:  zionless
#
# adding the word:  zionward
#
# adding the word:  zip
#
# adding the word:  zipa
#
# adding the word:  ziphian
#
# adding the word:  ziphiidae
#
# adding the word:  ziphiinae
#
# adding the word:  ziphioid
#
# adding the word:  ziphius
#
# adding the word:  zipless
#
# adding the word:  zipped
#
# adding the word:  zippeite
#
# adding the word:  zipper
#
# adding the word:  zippered
#
# adding the word:  zippering
#
# adding the word:  zippers
#
# adding the word:  zippy
#
# adding the word:  zippier
#
# adding the word:  zippiest
#
# adding the word:  zipping
#
# adding the word:  zippingly
#
# adding the word:  zipppier
#
# adding the word:  zipppiest
#
# adding the word:  zips
#
# adding the word:  zira
#
# adding the word:  zirai
#
# adding the word:  zirak
#
# adding the word:  ziram
#
# adding the word:  zirams
#
# adding the word:  zirbanit
#
# adding the word:  zircalloy
#
# adding the word:  zircaloy
#
# adding the word:  zircite
#
# adding the word:  zircofluoride
#
# adding the word:  zircon
#
# adding the word:  zirconate
#
# adding the word:  zirconia
#
# adding the word:  zirconian
#
# adding the word:  zirconias
#
# adding the word:  zirconic
#
# adding the word:  zirconiferous
#
# adding the word:  zirconifluoride
#
# adding the word:  zirconyl
#
# adding the word:  zirconium
#
# adding the word:  zirconofluoride
#
# adding the word:  zirconoid
#
# adding the word:  zircons
#
# adding the word:  zyrenian
#
# adding the word:  zirian
#
# adding the word:  zyrian
#
# adding the word:  zyryan
#
# adding the word:  zirianian
#
# adding the word:  zirkelite
#
# adding the word:  zirkite
#
# adding the word:  zit
#
# adding the word:  zythem
#
# adding the word:  zither
#
# adding the word:  zitherist
#
# adding the word:  zitherists
#
# adding the word:  zithern
#
# adding the word:  zitherns
#
# adding the word:  zithers
#
# adding the word:  zythia
#
# adding the word:  zythum
#
# adding the word:  ziti
#
# adding the word:  zitis
#
# adding the word:  zits
#
# adding the word:  zitter
#
# adding the word:  zittern
#
# adding the word:  zitzit
#
# adding the word:  zitzith
#
# adding the word:  zizany
#
# adding the word:  zizania
#
# adding the word:  zizel
#
# adding the word:  zizia
#
# adding the word:  zizyphus
#
# adding the word:  zizit
#
# adding the word:  zizith
#
# adding the word:  zyzomys
#
# adding the word:  zizz
#
# adding the word:  zyzzyva
#
# adding the word:  zyzzyvas
#
# adding the word:  zizzle
#
# adding the word:  zizzled
#
# adding the word:  zizzles
#
# adding the word:  zizzling
#
# adding the word:  zyzzogeton
#
# adding the word:  zlote
#
# adding the word:  zloty
#
# adding the word:  zlotych
#
# adding the word:  zloties
#
# adding the word:  zlotys
#
# adding the word:  zmudz
#
# adding the word:  zn
#
# adding the word:  zo
#
# adding the word:  zoa
#
# adding the word:  zoacum
#
# adding the word:  zoaea
#
# adding the word:  zoanthacea
#
# adding the word:  zoanthacean
#
# adding the word:  zoantharia
#
# adding the word:  zoantharian
#
# adding the word:  zoanthid
#
# adding the word:  zoanthidae
#
# adding the word:  zoanthidea
#
# adding the word:  zoanthodeme
#
# adding the word:  zoanthodemic
#
# adding the word:  zoanthoid
#
# adding the word:  zoanthropy
#
# adding the word:  zoanthus
#
# adding the word:  zoarces
#
# adding the word:  zoarcidae
#
# adding the word:  zoaria
#
# adding the word:  zoarial
#
# adding the word:  zoarite
#
# adding the word:  zoarium
#
# adding the word:  zobo
#
# adding the word:  zobtenite
#
# adding the word:  zocalo
#
# adding the word:  zocco
#
# adding the word:  zoccolo
#
# adding the word:  zod
#
# adding the word:  zodiac
#
# adding the word:  zodiacal
#
# adding the word:  zodiacs
#
# adding the word:  zodiophilous
#
# adding the word:  zoea
#
# adding the word:  zoeae
#
# adding the word:  zoeaform
#
# adding the word:  zoeal
#
# adding the word:  zoeas
#
# adding the word:  zoeform
#
# adding the word:  zoehemera
#
# adding the word:  zoehemerae
#
# adding the word:  zoetic
#
# adding the word:  zoetrope
#
# adding the word:  zoetropic
#
# adding the word:  zoftig
#
# adding the word:  zogan
#
# adding the word:  zogo
#
# adding the word:  zohak
#
# adding the word:  zoharist
#
# adding the word:  zoharite
#
# adding the word:  zoiatria
#
# adding the word:  zoiatrics
#
# adding the word:  zoic
#
# adding the word:  zoid
#
# adding the word:  zoidiophilous
#
# adding the word:  zoidogamous
#
# adding the word:  zoilean
#
# adding the word:  zoilism
#
# adding the word:  zoilist
#
# adding the word:  zoilus
#
# adding the word:  zoysia
#
# adding the word:  zoysias
#
# adding the word:  zoisite
#
# adding the word:  zoisites
#
# adding the word:  zoisitization
#
# adding the word:  zoism
#
# adding the word:  zoist
#
# adding the word:  zoistic
#
# adding the word:  zokor
#
# adding the word:  zolaesque
#
# adding the word:  zolaism
#
# adding the word:  zolaist
#
# adding the word:  zolaistic
#
# adding the word:  zolaize
#
# adding the word:  zoll
#
# adding the word:  zolle
#
# adding the word:  zollernia
#
# adding the word:  zollpfund
#
# adding the word:  zollverein
#
# adding the word:  zolotink
#
# adding the word:  zolotnik
#
# adding the word:  zombi
#
# adding the word:  zombie
#
# adding the word:  zombielike
#
# adding the word:  zombies
#
# adding the word:  zombiism
#
# adding the word:  zombiisms
#
# adding the word:  zombis
#
# adding the word:  zomotherapeutic
#
# adding the word:  zomotherapy
#
# adding the word:  zona
#
# adding the word:  zonaesthesia
#
# adding the word:  zonal
#
# adding the word:  zonality
#
# adding the word:  zonally
#
# adding the word:  zonar
#
# adding the word:  zonary
#
# adding the word:  zonaria
#
# adding the word:  zonate
#
# adding the word:  zonated
#
# adding the word:  zonation
#
# adding the word:  zonations
#
# adding the word:  zonda
#
# adding the word:  zone
#
# adding the word:  zoned
#
# adding the word:  zoneless
#
# adding the word:  zonelet
#
# adding the word:  zonelike
#
# adding the word:  zoner
#
# adding the word:  zoners
#
# adding the word:  zones
#
# adding the word:  zonesthesia
#
# adding the word:  zonetime
#
# adding the word:  zonetimes
#
# adding the word:  zongora
#
# adding the word:  zonic
#
# adding the word:  zoniferous
#
# adding the word:  zoning
#
# adding the word:  zonite
#
# adding the word:  zonites
#
# adding the word:  zonitid
#
# adding the word:  zonitidae
#
# adding the word:  zonitoides
#
# adding the word:  zonked
#
# adding the word:  zonnar
#
# adding the word:  zonochlorite
#
# adding the word:  zonociliate
#
# adding the word:  zonoid
#
# adding the word:  zonolimnetic
#
# adding the word:  zonoplacental
#
# adding the word:  zonoplacentalia
#
# adding the word:  zonoskeleton
#
# adding the word:  zonotrichia
#
# adding the word:  zonta
#
# adding the word:  zontian
#
# adding the word:  zonula
#
# adding the word:  zonulae
#
# adding the word:  zonular
#
# adding the word:  zonulas
#
# adding the word:  zonule
#
# adding the word:  zonules
#
# adding the word:  zonulet
#
# adding the word:  zonure
#
# adding the word:  zonurid
#
# adding the word:  zonuridae
#
# adding the word:  zonuroid
#
# adding the word:  zonurus
#
# adding the word:  zoo
#
# adding the word:  zoobenthoic
#
# adding the word:  zoobenthos
#
# adding the word:  zooblast
#
# adding the word:  zoocarp
#
# adding the word:  zoocecidium
#
# adding the word:  zoochem
#
# adding the word:  zoochemy
#
# adding the word:  zoochemical
#
# adding the word:  zoochemistry
#
# adding the word:  zoochlorella
#
# adding the word:  zoochore
#
# adding the word:  zoochores
#
# adding the word:  zoocyst
#
# adding the word:  zoocystic
#
# adding the word:  zoocytial
#
# adding the word:  zoocytium
#
# adding the word:  zoocoenocyte
#
# adding the word:  zoocultural
#
# adding the word:  zooculture
#
# adding the word:  zoocurrent
#
# adding the word:  zoodendria
#
# adding the word:  zoodendrium
#
# adding the word:  zoodynamic
#
# adding the word:  zoodynamics
#
# adding the word:  zooecia
#
# adding the word:  zooecial
#
# adding the word:  zooecium
#
# adding the word:  zooerastia
#
# adding the word:  zooerythrin
#
# adding the word:  zooflagellate
#
# adding the word:  zoofulvin
#
# adding the word:  zoogamete
#
# adding the word:  zoogamy
#
# adding the word:  zoogamous
#
# adding the word:  zoogene
#
# adding the word:  zoogenesis
#
# adding the word:  zoogeny
#
# adding the word:  zoogenic
#
# adding the word:  zoogenous
#
# adding the word:  zoogeog
#
# adding the word:  zoogeographer
#
# adding the word:  zoogeography
#
# adding the word:  zoogeographic
#
# adding the word:  zoogeographical
#
# adding the word:  zoogeographically
#
# adding the word:  zoogeographies
#
# adding the word:  zoogeology
#
# adding the word:  zoogeological
#
# adding the word:  zoogeologist
#
# adding the word:  zooglea
#
# adding the word:  zoogleae
#
# adding the word:  zoogleal
#
# adding the word:  zoogleas
#
# adding the word:  zoogler
#
# adding the word:  zoogloea
#
# adding the word:  zoogloeae
#
# adding the word:  zoogloeal
#
# adding the word:  zoogloeas
#
# adding the word:  zoogloeic
#
# adding the word:  zoogony
#
# adding the word:  zoogonic
#
# adding the word:  zoogonidium
#
# adding the word:  zoogonous
#
# adding the word:  zoograft
#
# adding the word:  zoografting
#
# adding the word:  zoographer
#
# adding the word:  zoography
#
# adding the word:  zoographic
#
# adding the word:  zoographical
#
# adding the word:  zoographically
#
# adding the word:  zoographist
#
# adding the word:  zooid
#
# adding the word:  zooidal
#
# adding the word:  zooidiophilous
#
# adding the word:  zooids
#
# adding the word:  zookers
#
# adding the word:  zooks
#
# adding the word:  zool
#
# adding the word:  zoolater
#
# adding the word:  zoolaters
#
# adding the word:  zoolatry
#
# adding the word:  zoolatria
#
# adding the word:  zoolatries
#
# adding the word:  zoolatrous
#
# adding the word:  zoolite
#
# adding the word:  zoolith
#
# adding the word:  zoolithic
#
# adding the word:  zoolitic
#
# adding the word:  zoologer
#
# adding the word:  zoology
#
# adding the word:  zoologic
#
# adding the word:  zoological
#
# adding the word:  zoologically
#
# adding the word:  zoologicoarchaeologist
#
# adding the word:  zoologicobotanical
#
# adding the word:  zoologies
#
# adding the word:  zoologist
#
# adding the word:  zoologists
#
# adding the word:  zoologize
#
# adding the word:  zoologized
#
# adding the word:  zoologizing
#
# adding the word:  zoom
#
# adding the word:  zoomagnetic
#
# adding the word:  zoomagnetism
#
# adding the word:  zoomancy
#
# adding the word:  zoomania
#
# adding the word:  zoomanias
#
# adding the word:  zoomantic
#
# adding the word:  zoomantist
#
# adding the word:  zoomastigina
#
# adding the word:  zoomastigoda
#
# adding the word:  zoomechanical
#
# adding the word:  zoomechanics
#
# adding the word:  zoomed
#
# adding the word:  zoomelanin
#
# adding the word:  zoometry
#
# adding the word:  zoometric
#
# adding the word:  zoometrical
#
# adding the word:  zoometries
#
# adding the word:  zoomimetic
#
# adding the word:  zoomimic
#
# adding the word:  zooming
#
# adding the word:  zoomorph
#
# adding the word:  zoomorphy
#
# adding the word:  zoomorphic
#
# adding the word:  zoomorphism
#
# adding the word:  zoomorphize
#
# adding the word:  zoomorphs
#
# adding the word:  zooms
#
# adding the word:  zoon
#
# adding the word:  zoona
#
# adding the word:  zoonal
#
# adding the word:  zoonerythrin
#
# adding the word:  zoonic
#
# adding the word:  zoonist
#
# adding the word:  zoonite
#
# adding the word:  zoonitic
#
# adding the word:  zoonomy
#
# adding the word:  zoonomia
#
# adding the word:  zoonomic
#
# adding the word:  zoonomical
#
# adding the word:  zoonomist
#
# adding the word:  zoonoses
#
# adding the word:  zoonosis
#
# adding the word:  zoonosology
#
# adding the word:  zoonosologist
#
# adding the word:  zoonotic
#
# adding the word:  zoons
#
# adding the word:  zoonule
#
# adding the word:  zoopaleontology
#
# adding the word:  zoopantheon
#
# adding the word:  zooparasite
#
# adding the word:  zooparasitic
#
# adding the word:  zoopathy
#
# adding the word:  zoopathology
#
# adding the word:  zoopathological
#
# adding the word:  zoopathologies
#
# adding the word:  zoopathologist
#
# adding the word:  zooperal
#
# adding the word:  zoopery
#
# adding the word:  zooperist
#
# adding the word:  zoophaga
#
# adding the word:  zoophagan
#
# adding the word:  zoophagineae
#
# adding the word:  zoophagous
#
# adding the word:  zoophagus
#
# adding the word:  zoopharmacy
#
# adding the word:  zoopharmacological
#
# adding the word:  zoophile
#
# adding the word:  zoophiles
#
# adding the word:  zoophily
#
# adding the word:  zoophilia
#
# adding the word:  zoophiliac
#
# adding the word:  zoophilic
#
# adding the word:  zoophilies
#
# adding the word:  zoophilism
#
# adding the word:  zoophilist
#
# adding the word:  zoophilite
#
# adding the word:  zoophilitic
#
# adding the word:  zoophilous
#
# adding the word:  zoophysical
#
# adding the word:  zoophysicist
#
# adding the word:  zoophysics
#
# adding the word:  zoophysiology
#
# adding the word:  zoophism
#
# adding the word:  zoophyta
#
# adding the word:  zoophytal
#
# adding the word:  zoophyte
#
# adding the word:  zoophytes
#
# adding the word:  zoophytic
#
# adding the word:  zoophytical
#
# adding the word:  zoophytish
#
# adding the word:  zoophytography
#
# adding the word:  zoophytoid
#
# adding the word:  zoophytology
#
# adding the word:  zoophytological
#
# adding the word:  zoophytologist
#
# adding the word:  zoophobe
#
# adding the word:  zoophobes
#
# adding the word:  zoophobia
#
# adding the word:  zoophobous
#
# adding the word:  zoophori
#
# adding the word:  zoophoric
#
# adding the word:  zoophorous
#
# adding the word:  zoophorus
#
# adding the word:  zooplankton
#
# adding the word:  zooplanktonic
#
# adding the word:  zooplasty
#
# adding the word:  zooplastic
#
# adding the word:  zoopraxiscope
#
# adding the word:  zoopsia
#
# adding the word:  zoopsychology
#
# adding the word:  zoopsychological
#
# adding the word:  zoopsychologist
#
# adding the word:  zoos
#
# adding the word:  zooscopy
#
# adding the word:  zooscopic
#
# adding the word:  zoosis
#
# adding the word:  zoosmosis
#
# adding the word:  zoosperm
#
# adding the word:  zoospermatic
#
# adding the word:  zoospermia
#
# adding the word:  zoospermium
#
# adding the word:  zoosperms
#
# adding the word:  zoospgia
#
# adding the word:  zoosphere
#
# adding the word:  zoosporange
#
# adding the word:  zoosporangia
#
# adding the word:  zoosporangial
#
# adding the word:  zoosporangiophore
#
# adding the word:  zoosporangium
#
# adding the word:  zoospore
#
# adding the word:  zoospores
#
# adding the word:  zoosporic
#
# adding the word:  zoosporiferous
#
# adding the word:  zoosporocyst
#
# adding the word:  zoosporous
#
# adding the word:  zoosterol
#
# adding the word:  zootaxy
#
# adding the word:  zootaxonomist
#
# adding the word:  zootechny
#
# adding the word:  zootechnic
#
# adding the word:  zootechnical
#
# adding the word:  zootechnician
#
# adding the word:  zootechnics
#
# adding the word:  zooter
#
# adding the word:  zoothecia
#
# adding the word:  zoothecial
#
# adding the word:  zoothecium
#
# adding the word:  zootheism
#
# adding the word:  zootheist
#
# adding the word:  zootheistic
#
# adding the word:  zootherapy
#
# adding the word:  zoothome
#
# adding the word:  zooty
#
# adding the word:  zootic
#
# adding the word:  zootype
#
# adding the word:  zootypic
#
# adding the word:  zootoca
#
# adding the word:  zootomy
#
# adding the word:  zootomic
#
# adding the word:  zootomical
#
# adding the word:  zootomically
#
# adding the word:  zootomies
#
# adding the word:  zootomist
#
# adding the word:  zoototemism
#
# adding the word:  zootoxin
#
# adding the word:  zootrophy
#
# adding the word:  zootrophic
#
# adding the word:  zooxanthella
#
# adding the word:  zooxanthellae
#
# adding the word:  zooxanthin
#
# adding the word:  zoozoo
#
# adding the word:  zophophori
#
# adding the word:  zophori
#
# adding the word:  zophorus
#
# adding the word:  zopilote
#
# adding the word:  zoque
#
# adding the word:  zoquean
#
# adding the word:  zoraptera
#
# adding the word:  zorgite
#
# adding the word:  zori
#
# adding the word:  zoril
#
# adding the word:  zorilla
#
# adding the word:  zorillas
#
# adding the word:  zorille
#
# adding the word:  zorilles
#
# adding the word:  zorillinae
#
# adding the word:  zorillo
#
# adding the word:  zorillos
#
# adding the word:  zorils
#
# adding the word:  zoris
#
# adding the word:  zoroaster
#
# adding the word:  zoroastra
#
# adding the word:  zoroastrian
#
# adding the word:  zoroastrianism
#
# adding the word:  zoroastrians
#
# adding the word:  zoroastrism
#
# adding the word:  zorotypus
#
# adding the word:  zorrillo
#
# adding the word:  zorro
#
# adding the word:  zortzico
#
# adding the word:  zosma
#
# adding the word:  zoster
#
# adding the word:  zostera
#
# adding the word:  zosteraceae
#
# adding the word:  zosteriform
#
# adding the word:  zosteropinae
#
# adding the word:  zosterops
#
# adding the word:  zosters
#
# adding the word:  zouave
#
# adding the word:  zouaves
#
# adding the word:  zounds
#
# adding the word:  zowie
#
# adding the word:  zs
#
# adding the word:  zubeneschamali
#
# adding the word:  zubr
#
# adding the word:  zuccarino
#
# adding the word:  zucchetti
#
# adding the word:  zucchetto
#
# adding the word:  zucchettos
#
# adding the word:  zucchini
#
# adding the word:  zucchinis
#
# adding the word:  zucco
#
# adding the word:  zuchetto
#
# adding the word:  zudda
#
# adding the word:  zuffolo
#
# adding the word:  zufolo
#
# adding the word:  zugtierlast
#
# adding the word:  zugtierlaster
#
# adding the word:  zugzwang
#
# adding the word:  zuisin
#
# adding the word:  zuleika
#
# adding the word:  zulhijjah
#
# adding the word:  zulinde
#
# adding the word:  zulkadah
#
# adding the word:  zulu
#
# adding the word:  zuludom
#
# adding the word:  zuluize
#
# adding the word:  zulus
#
# adding the word:  zumatic
#
# adding the word:  zumbooruk
#
# adding the word:  zuni
#
# adding the word:  zunian
#
# adding the word:  zunyite
#
# adding the word:  zunis
#
# adding the word:  zupanate
#
# adding the word:  zurich
#
# adding the word:  zurlite
#
# adding the word:  zutugil
#
# adding the word:  zuurveldt
#
# adding the word:  zuza
#
# adding the word:  zwanziger
#
# adding the word:  zwieback
#
# adding the word:  zwiebacks
#
# adding the word:  zwieselite
#
# adding the word:  zwinglian
#
# adding the word:  zwinglianism
#
# adding the word:  zwinglianist
#
# adding the word:  zwitter
#
# adding the word:  zwitterion
#
# adding the word:  zwitterionic
# 1

# %%
trie.search('bet')
# Out:
# False

# %%
# Out:
# False
